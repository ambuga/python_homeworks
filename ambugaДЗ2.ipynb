# %%
# Базовая часть
# -*- coding: utf8 -*-

s1 = ["""Телефон абонента: +7 916 000 00 01
Время: 10:34
Дата: 20.05.2017
Оценка: 1
Длительность разговора (мин.): 0:32
Комментарий: Общение с сотрудником вашей техподдержки мне не понравилось. Раньше всегда отвечала девушка с приятным голосом, а сегодня какой-то мужчина. Совсем никуда не годится, примите меры!!!""",
"""Телефон абонента: +7 916 000 00 02
Время: 9:20
Дата: 21.05.2017
Оценка: 5
Длительность разговора (мин.): 25:07
Комментарий: С моей проблемой мне помогли, большое спасибо!"""]
dic = {}
for s in s1:
    ddd = {}
    for line in s.split('\n'):
        if line:
            splitted_line = line.split(': ')
            field_name = splitted_line[0]
            field_value = splitted_line[1]
            ddd[field_name]=field_value
    dic[ddd['Телефон абонента']] = ddd

     
for key in dic.keys():
    print key
    for key2 in dic[key]:
        print ('{0}: {1}'.format(key2, dic[key][key2]))

# Проверка
dic['+7 916 000 00 01']['Дата'] == '20.05.2017'
# Out:
# +7 916 000 00 02
# Оценка: 5
# Время: 9:20
# Комментарий: С моей проблемой мне помогли, большое спасибо!
# Длительность разговора (мин.): 25:07
# Телефон абонента: +7 916 000 00 02
# Дата: 21.05.2017
# +7 916 000 00 01
# Оценка: 1
# Время: 10:34
# Комментарий: Общение с сотрудником вашей техподдержки мне не понравилось. Раньше всегда отвечала девушка с приятным голосом, а сегодня какой-то мужчина. Совсем никуда не годится, примите меры!!!
# Длительность разговора (мин.): 0:32
# Телефон абонента: +7 916 000 00 01
# Дата: 20.05.2017
# True

# %%
# Продвинутая часть
#_*_coding: utf-8_*_
from datetime import datetime
 
s1 = ["""Телефон абонента: +7 916 000 00 01
Время: 10:34
Дата: 20.05.2017
Оценка: 1
Длительность разговора (мин.): 0:32
Комментарий: Общение с сотрудником вашей техподдержки мне не понравилось. Раньше всегда отвечала девушка с приятным голосом, а сегодня какой-то мужчина. Совсем никуда не годится, примите меры!!!""",
"""Телефон абонента: +7 916 000 00 02
Время: 9:20
Дата: 21.05.2017
Оценка: 5
Длительность разговора (мин.): 25:07
Комментарий: С моей проблемой мне помогли, большое спасибо!"""]
dic = {}
for s in s1:
    ddd = {}
    for line in s.split('\n'):
        if line:
            splitted_line = line.split(': ')
            field_name = splitted_line[0]
            field_value = splitted_line[1]
            ddd[field_name]=field_value
    ddd['Дата время'] = datetime.strptime(ddd['Дата'] + ' ' + ddd['Время'], '%d.%m.%Y %H:%M')
    del ddd['Дата']
    del ddd['Время']
    ddd['Телефон абонента'] = int(ddd['Телефон абонента'].replace(' ','').replace('+',''))
    dic[ddd['Телефон абонента']] = ddd
    
 
for key in dic.keys():
    print key
    for key2 in dic[key]:
        print ('{0}: {1}'.format(key2, dic[key][key2]))
# Out:
# 79160000001
# Оценка: 1
# Дата время: 2017-05-20 10:34:00
# Комментарий: Общение с сотрудником вашей техподдержки мне не понравилось. Раньше всегда отвечала девушка с приятным голосом, а сегодня какой-то мужчина. Совсем никуда не годится, примите меры!!!
# Длительность разговора (мин.): 0:32
# Телефон абонента: 79160000001
# 79160000002
# Оценка: 5
# Дата время: 2017-05-21 09:20:00
# Комментарий: С моей проблемой мне помогли, большое спасибо!
# Длительность разговора (мин.): 25:07
# Телефон абонента: 79160000002

# %%
# Сложная часть
t = (0, 1, 2, 3, 4)
l = list(t)
l.append(5)
print type(l)
t = tuple(l)
print type(t)

s = {t}
print s

items = [('Phone','79160000001'),('Grade',1)]
d = dict(items)
print d
# Out:
# <type 'list'>
# <type 'tuple'>
# set([(0, 1, 2, 3, 4, 5)])
# {'Grade': 1, 'Phone': '79160000001'}
